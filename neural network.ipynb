# %% [markdown]
# <a href="https://colab.research.google.com/github/abdelfattah99/Security-Task1/blob/main/neural%20network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense

# %%
# Generate some sample data
x = np.linspace(-1, 1, 100)
y = 2 * x**3 + np.random.randn(*x.shape) * 0.2

# Create a neural network model
model = Sequential()
model.add(Dense(10, input_dim=1, activation='relu'))
model.add(Dense(1, activation='linear'))
model.compile(loss='mean_squared_error', optimizer='adam')

# Train the model
model.fit(x, y, epochs=100, batch_size=10)

# Make predictions
y_pred = model.predict(x)

# Plot the original data and the predicted values
plt.scatter(x, y, color='blue', label='Original')
plt.plot(x, y_pred, color='red', label='Predicted')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 10/10 [==============================] - 2s 10ms/step - loss: 0.8109
# Epoch 2/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7644
# Epoch 3/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.7154
# Epoch 4/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6739
# Epoch 5/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6359
# Epoch 6/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5960
# Epoch 7/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.5614
# Epoch 8/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5320
# Epoch 9/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5016
# Epoch 10/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4746
# Epoch 11/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4502
# Epoch 12/100
# ...
